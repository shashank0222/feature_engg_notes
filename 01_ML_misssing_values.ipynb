# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# check missing values

df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#  one easiest way to delete missing values is delete the rows with missing values

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#  column wise

# %%
df.dropna(axis=1)
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0           0       3    male      1      0   7.2500   Third    man
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# ...

# %% [markdown]
# #  IMputation missing values

# %% [markdown]
# ## 1 mean value imputation

# %%
sns.displot(df["age"])

# %%
sns.histplot(df["age"] , kde =True)
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
df["age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
df["age_mean"] = df["age"].fillna(df["age"].mean())

# %%
df[["age_mean" , "age"]]
# Out:
#       age_mean   age
# 0    22.000000  22.0
# 1    38.000000  38.0
# 2    26.000000  26.0
# 3    35.000000  35.0
# 4    35.000000  35.0
# ..         ...   ...
# 886  27.000000  27.0
# 887  19.000000  19.0
# 888  29.699118   NaN
# 889  26.000000  26.0
# 890  32.000000  32.0
#
# [891 rows x 2 columns]

# %%
sns.histplot(df["age_mean"] , kde = True)
# Out:
# <AxesSubplot: xlabel='age_mean', ylabel='Count'>

# %% [markdown]
# #  median imputation - when outliers are present

# %%
df["age_median"] = df["age"].fillna(df["age"].median())

# %%
df[["age_median" ,"age"]]
# Out:
#      age_median   age
# 0          22.0  22.0
# 1          38.0  38.0
# 2          26.0  26.0
# 3          35.0  35.0
# 4          35.0  35.0
# ..          ...   ...
# 886        27.0  27.0
# 887        19.0  19.0
# 888        28.0   NaN
# 889        26.0  26.0
# 890        32.0  32.0
#
# [891 rows x 2 columns]

# %%
sns.histplot(df["age_median"] , kde=True)
# Out:
# <AxesSubplot: xlabel='age_median', ylabel='Count'>

# %% [markdown]
# # mode imputation  = when catergorical variables are used

# %%
df["embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 891, dtype: object

# %%
df[df["embarked"].isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone  age_mean  age_median
# 61   woman       False    B         NaN   yes   True      38.0        38.0
# 829  woman       False    B         NaN   yes   True      62.0        62.0

# %%
mode_value = df[df["embarked"].notna()]["embarked"].mode()[0]

# %%
mode_value
# Out:
# 'S'

# %%
df["embarked_mode"] = df["embarked"].fillna(mode_value)

# %%
df[["embarked_mode" , "embarked"]]
# Out:
#     embarked_mode embarked
# 0               S        S
# 1               C        C
# 2               S        S
# 3               S        S
# 4               S        S
# ..            ...      ...
# 886             S        S
# 887             S        S
# 888             S        S
# 889             C        C
# 890             Q        Q
#
# [891 rows x 2 columns]

# %%
df["embarked_mode"].isnull().sum()
# Out:
# 0

# %%
sns.scatterplot(df["embarked"])

# %% [markdown]
# # random smapling

# %%
import numpy as np

# %%
sample = np.random.randint(1,10,100)

# %%
sample
# Out:
# array([4, 1, 3, 7, 6, 2, 5, 1, 1, 4, 7, 7, 4, 6, 1, 3, 9, 8, 4, 5, 5, 2,
#        3, 1, 5, 4, 7, 8, 6, 1, 5, 9, 5, 8, 4, 4, 1, 5, 9, 8, 2, 3, 6, 6,
#        1, 3, 1, 1, 3, 6, 6, 3, 9, 9, 2, 8, 6, 8, 1, 5, 6, 1, 5, 2, 2, 1,
#        2, 8, 5, 9, 1, 4, 1, 7, 3, 5, 8, 9, 5, 2, 8, 8, 8, 1, 2, 3, 5, 3,
#        5, 1, 1, 7, 7, 4, 7, 7, 6, 9, 2, 8])

# %%
sample2 = np.random.choice(sample , 10)

# %%
sample2
# Out:
# array([1, 9, 3, 8, 6, 5, 5, 7, 5, 5])

# %%
value = np.random.choice(df["embarked"],1)[0]

# %%
value
# Out:
# 'S'

# %%
df["random_sampling"] = df["embarked"].fillna(value)

# %%
df[["random_sampling" , "embarked"]]
# Out:
#     random_sampling embarked
# 0                 S        S
# 1                 C        C
# 2                 S        S
# 3                 S        S
# 4                 S        S
# ..              ...      ...
# 886               S        S
# 887               S        S
# 888               S        S
# 889               C        C
# 890               Q        Q
#
# [891 rows x 2 columns]

# %%
df["random_sampling"].isnull().sum()
# Out:
# 0

# %%
df["embarked"].isnull().sum()
# Out:
# 2
